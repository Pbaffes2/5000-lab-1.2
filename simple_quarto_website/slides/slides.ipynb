# %% [raw]
# ---
# title: "My First Ever Slideshow"
# author: "Pavlos Baffes"
# format:
#   revealjs:
#     code-fold: show
#     code-tools: true
# execute:
#   enabled: true
#   echo: true
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Slide 1
#
# This is my first slide
#
# ## Georgetown!
# This is an image of Georgetown University.
# ![Georgetown!](images/Georgetown.png)
#
# ## UMD!
# This is an image of the University of Maryland.
# ![UMD!](images/University-of Maryland.png)
#
# ## Oil!
# Oil prices fell between June 2014 and January 2015, a significant drop, but not unprecedented. [@baffes2015great]
#
# ## Code!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

x= np.arange(0,10)
y= np.arange(0,10)

plt.plot(x, y)
plt.show()

print("This is my amazing line")
# Out:
# This is my amazing line

# %% [markdown]
# ## Citations!
